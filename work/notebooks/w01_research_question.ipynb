# %% [markdown]
# <a href="https://colab.research.google.com/github/Nhlalenhle/FlyRank-Nhlalenhle/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Nhlalenhle/FlyRank-Nhlalenhle/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## 1. My lane
#pipeline already demonstrates the core loop (rank pages by refresh need),
#refreshing from one that isn't — beyond just the baseline rule.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## 2. The question
#- Unit of analysis: a single page (one row = one page's 90-day performance)
#- Decision this informs: which pages an editor should prioritize refreshing this month
#- Action: an editor spends time rewriting/updating a specific page instead of others
#- Cost of a wrong call:
#  - False positive (flagged, but not actually declining): wasted editor hours
#  - False negative (missed, but actually declining): page keeps losing traffic unnoticed
#- Why data/ML helps: with ~30,000 pages, nobody can manually review each one —
#  need a way to rank pages by refresh-worthiness so editor time goes to the
#  highest-value pages first

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Number 1: how many pages are currently "declining"?
declining_pct = (df["trend_direction"] == "down").mean()
print(f"{declining_pct:.1%} of pages are declining")

# Number 2: of declining pages, how many also have meaningful traffic
# (worth prioritizing vs. a dead page nobody will notice)?
declining = df[df["trend_direction"] == "down"]
meaningful = (declining["impressions_90d"] >= 100).mean()
print(f"{meaningful:.1%} of declining pages still get >=100 impressions/90d")

# Number 3: does position tier relate to decline risk?
# (do lower-ranked pages decline more often?)
decline_by_tier = df.groupby("position_tier")["trend_direction"].apply(
    lambda x: (x == "down").mean()
)
print(decline_by_tier.round(3))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_592/3427686677.py in <cell line: 0>()
#       2 # Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#       3 import pandas as pd
# ----> 4 df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
#       5
#       6 # Number 1: how many pages are currently "declining"?
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## 4. Careful words
#What I can claim: these are observed patterns in this anonymized sample —
#directional signals that could inform a prioritization score, not proof
#of causality or of how any search engine ranks pages.
#What I can't claim: that any factor "causes" decline, or that this reflects
#how Google's algorithm works.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
